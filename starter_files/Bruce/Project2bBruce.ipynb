# %%
#imports
import pandas as pd
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import scipy.stats as st
import quandl
from quandl_apitoken import api_key

# %%
try:
    copper_download = quandl.get("CHRIS/CME_HG2", authtoken=api_key)
    gold_download = quandl.get("CHRIS/CME_GC2", authtoken=api_key)
    SP500_download = quandl.get("CHRIS/CME_ES2", authtoken=api_key)
    
    copper_download.to_csv("copper_2nd.csv")
    gold_download.to_csv("gold_2nd.csv")
    SP500_download.to_csv("SP500_2nd.csv")
    

except Exception as e:
    print(e)

# %%
csv_file = os.path.join("copper_2nd.csv")
copper_raw_df = pd.read_csv(csv_file)
copper_raw_df.head()
# Out:
#          Date    Open    High     Low    Last  Change  Settle  Volume  \
# 0  1959-10-29  0.3240  0.3240  0.3190  0.3240     NaN  0.3240    79.0
# 1  1959-10-30  0.3215  0.3278  0.3210  0.3215     NaN  0.3215   100.0
# 2  1959-11-02  0.3230  0.3230  0.3180  0.3230     NaN  0.3230    88.0
# 3  1959-11-04  0.3300  0.3307  0.3259  0.3300     NaN  0.3300   135.0
# 4  1959-11-05  0.3310  0.3340  0.3310  0.3310     NaN  0.3310   161.0
#
#    Previous Day Open Interest
# 0                       582.0
# 1                       592.0
# 2                       587.0
# 3                       577.0
# 4                       617.0

# %%
SP500 = 'SP500_2nd.csv'
SP500_df= pd.read_csv(SP500)
SP500_df.tail()
# Out:
#             Date     Open     High      Low    Last  Change   Settle  \
# 5790  2020-06-10  3194.25  3216.75  3168.75  3173.5   19.00  3175.50
# 5791  2020-06-11  3173.00  3177.75  2985.25  3003.0  176.00  2999.50
# 5792  2020-06-12  3000.75  3076.75  2971.00  3024.5   24.25  3023.75
# 5793  2020-06-15  2983.25  3068.25  2923.75  3065.5   38.25  3062.00
# 5794  2020-06-16  3065.25  3156.25  3060.25  3116.0   56.25  3118.25
#
#          Volume  Previous Day Open Interest
# 5790   160381.0                    151588.0
# 5791   802407.0                    193508.0
# 5792  2715442.0                    414547.0
# 5793  2958270.0                    906306.0
# 5794  2979960.0                   1678383.0

# %%
SP500_df = SP500_df.sort_index(axis=0, ascending=True)
SP500_df.head()
# Out:
#          Date    Open    High     Low    Last  Change  Settle   Volume  \
# 0  1997-09-09  943.50  951.00  941.50  944.00     NaN  944.00    896.0
# 1  1997-09-10  942.75  943.25  917.00  925.00     NaN  925.00  12261.0
# 2  1997-09-11  924.00  929.75  910.25  918.25     NaN  918.25   9759.0
# 3  1997-09-12  918.00  936.50  913.50  933.75     NaN  933.75  18496.0
# 4  1997-09-15  933.50  939.75  929.00  931.50     NaN  931.50  11749.0
#
#    Previous Day Open Interest
# 0                       273.0
# 1                       382.0
# 2                      2909.0
# 3                      4059.0
# 4                      3818.0

# %%
sp500_percent_return = []
previous_price = 943.5
for index , row in SP500_df.iterrows():
    Settle_row = row["Settle"]
    dailySP500_return = (Settle_row - previous_price) / previous_price *100
    sp500_percent_return.append(round(dailySP500_return, 2))
    previous_price = Settle_row
SP500_df.insert(1,"SP_Daily_Pct_Return", sp500_percent_return)

# %%
SP500_df["Date"] = pd.to_datetime(SP500_df["Date"])

# %%
SP_dates = SP500_df.loc[(SP500_df["Date"] >= "1996-12-31") & 
                                   (SP500_df["Date"] <= "2020-06-10")]
SP_dates.head()
# Out:
#         Date  SP_Daily_Pct_Return    Open    High     Low    Last  Change  \
# 0 1997-09-09                 0.05  943.50  951.00  941.50  944.00     NaN
# 1 1997-09-10                -2.01  942.75  943.25  917.00  925.00     NaN
# 2 1997-09-11                -0.73  924.00  929.75  910.25  918.25     NaN
# 3 1997-09-12                 1.69  918.00  936.50  913.50  933.75     NaN
# 4 1997-09-15                -0.24  933.50  939.75  929.00  931.50     NaN
#
#    Settle   Volume  Previous Day Open Interest
# 0  944.00    896.0                       273.0
# 1  925.00  12261.0                       382.0
# 2  918.25   9759.0                      2909.0
# 3  933.75  18496.0                      4059.0
# 4  931.50  11749.0                      3818.0

# %%
SP_dates['SP_MA'] = SP_dates.rolling(55).mean()['SP_Daily_Pct_Return']
SP_dates.tail()
# Out:
# C:\Users\bruce\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Date  SP_Daily_Pct_Return     Open     High      Low    Last  \
# 5786 2020-06-04                -0.22  3106.75  3115.75  3077.00  3103.0
# 5787 2020-06-05                 2.48  3102.25  3199.75  3096.00  3175.0
# 5788 2020-06-08                 1.27  3181.50  3220.50  3173.00  3215.5
# 5789 2020-06-09                -0.69  3216.00  3220.00  3179.00  3194.5
# 5790 2020-06-10                -0.59  3194.25  3216.75  3168.75  3173.5
#
#       Change   Settle    Volume  Previous Day Open Interest     SP_MA
# 5786    6.75  3099.75   31864.0                     57382.0  0.435818
# 5787   76.75  3176.50   56532.0                     66325.0  0.542364
# 5788   40.25  3216.75   89946.0                     75367.0  0.574909
# 5789   22.25  3194.50   92923.0                    127169.0  0.638909
# 5790   19.00  3175.50  160381.0                    151588.0  0.688000

# %%
copper = 'copper_2nd.csv'
copper_df = pd.read_csv(copper)
print(copper_df.shape)
# Out:
# (9989, 9)

# %%
gold = 'gold_2nd.csv'
gold_df = pd.read_csv(gold)
print(copper_df.shape)
# Out:
# (9989, 9)

# %%
copp_gold_df = pd.merge(gold_df, copper_df, on=["Date"])
copp_gold_df.head()
# Out:
#          Date  Open_x  High_x  Low_x  Last_x  Change_x  Settle_x  Volume_x  \
# 0  1975-09-26   136.1   139.3  136.1   139.0       NaN     139.0     972.0
# 1  1975-09-29   138.2   141.3  138.2   139.8       NaN     139.8    1012.0
# 2  1975-09-30   141.5   143.9  141.5   142.2       NaN     142.2     947.0
# 3  1975-10-01   145.0   145.8  143.6   144.2       NaN     144.2    1153.0
# 4  1975-10-02   145.0   146.2  142.5   143.4       NaN     143.4    1159.0
#
#    Previous Day Open Interest_x  Open_y  High_y  Low_y  Last_y  Change_y  \
# 0                        4713.0   0.573   0.581  0.573   0.580       NaN
# 1                        4626.0   0.578   0.578  0.575   0.575       NaN
# 2                        4556.0   0.572   0.579  0.571   0.571       NaN
# 3                        4510.0   0.575   0.575  0.571   0.572       NaN
# 4                        4254.0   0.570   0.570  0.567   0.568       NaN
#
#    Settle_y  Volume_y  Previous Day Open Interest_y
# 0     0.580      51.0                        2174.0
# 1     0.575      78.0                        2179.0
# 2     0.571      35.0                        2169.0
# 3     0.572      99.0                        2151.0
# 4     0.568      20.0                        2144.0

# %%
copp_gold_df = pd.DataFrame({
    "Date": copp_gold_df["Date"],
    "Gold Price": copp_gold_df["Settle_x"],
    "Copper Price": copp_gold_df["Settle_y"]
})
copp_gold_df
# Out:
#             Date  Gold Price  Copper Price
# 0     1975-09-26       139.0        0.5800
# 1     1975-09-29       139.8        0.5750
# 2     1975-09-30       142.2        0.5710
# 3     1975-10-01       144.2        0.5720
# 4     1975-10-02       143.4        0.5680
# ...          ...         ...           ...
# 8682  2020-06-10      1720.7        2.6565
# 8683  2020-06-11      1739.8        2.5865
# 8684  2020-06-12      1737.3        2.6000
# 8685  2020-06-15      1727.2        2.5670
# 8686  2020-06-16      1736.5        2.5645
#
# [8687 rows x 3 columns]

# %%
copp_gold_df_corr = st.pearsonr(copp_gold_df["Gold Price"],copp_gold_df["Copper Price"])[0]
print(copp_gold_df_corr)
# Out:
# 0.865046879892616

# %%
gold_copp_ratio = (copp_gold_df["Copper Price"] / copp_gold_df["Gold Price"])

# %%
copp_gold_df.insert(3,"GoldCopperRatio", gold_copp_ratio)
copp_gold_df.tail()
# Out:
#             Date  Gold Price  Copper Price  GoldCopperRatio
# 8682  2020-06-10      1720.7        2.6565         0.001544
# 8683  2020-06-11      1739.8        2.5865         0.001487
# 8684  2020-06-12      1737.3        2.6000         0.001497
# 8685  2020-06-15      1727.2        2.5670         0.001486
# 8686  2020-06-16      1736.5        2.5645         0.001477

# %%
copp_gold_df = copp_gold_df.sort_index(axis=0, ascending=True)
copp_gold_df.head()
# Out:
#          Date  Gold Price  Copper Price  GoldCopperRatio
# 0  1975-09-26       139.0         0.580         0.004173
# 1  1975-09-29       139.8         0.575         0.004113
# 2  1975-09-30       142.2         0.571         0.004015
# 3  1975-10-01       144.2         0.572         0.003967
# 4  1975-10-02       143.4         0.568         0.003961

# %%
copp_gold_percent_chg = []
previous_price = .002849
for index , row in copp_gold_df.iterrows():
    GcR_row = row["GoldCopperRatio"]
    GcR_daily_pctchg = (GcR_row - previous_price) / previous_price *100
    copp_gold_percent_chg.append(round(GcR_daily_pctchg, 2))
    previous_price = GcR_row
copp_gold_df.insert(1,"Gold-Copp Dly Ret", copp_gold_percent_chg)
copp_gold_df.tail()
# Out:
#             Date  Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio
# 8682  2020-06-10               2.28      1720.7        2.6565         0.001544
# 8683  2020-06-11              -3.70      1739.8        2.5865         0.001487
# 8684  2020-06-12               0.67      1737.3        2.6000         0.001497
# 8685  2020-06-15              -0.69      1727.2        2.5670         0.001486
# 8686  2020-06-16              -0.63      1736.5        2.5645         0.001477

# %%
copp_gold_df.head()
# Out:
#          Date  Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio
# 0  1975-09-26              46.46       139.0         0.580         0.004173
# 1  1975-09-29              -1.43       139.8         0.575         0.004113
# 2  1975-09-30              -2.37       142.2         0.571         0.004015
# 3  1975-10-01              -1.21       144.2         0.572         0.003967
# 4  1975-10-02              -0.15       143.4         0.568         0.003961

# %%
copp_gold_df["Date"] = pd.to_datetime(copp_gold_df["Date"])

# %%
copp_gold_dates_df = copp_gold_df.loc[(copp_gold_df["Date"] >= "1998-04-09") & 
                                   (copp_gold_df["Date"] <= "2020-06-10")]

copp_gold_dates_df
# Out:
#            Date  Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio
# 3166 1998-04-09               3.88       310.2        0.8105         0.002613
# 3167 1998-04-13               0.48       312.9        0.8215         0.002625
# 3168 1998-04-14               0.51       310.0        0.8180         0.002639
# 3169 1998-04-15               5.05       309.0        0.8565         0.002772
# 3170 1998-04-16              -2.94       309.8        0.8335         0.002690
# ...         ...                ...         ...           ...              ...
# 8678 2020-06-04              -1.23      1727.4        2.4895         0.001441
# 8679 2020-06-05               5.36      1683.0        2.5555         0.001518
# 8680 2020-06-08              -0.91      1705.1        2.5655         0.001505
# 8681 2020-06-09               0.32      1721.9        2.5990         0.001509
# 8682 2020-06-10               2.28      1720.7        2.6565         0.001544
#
# [5517 rows x 5 columns]

# %%
forcorr_df = pd.merge(copp_gold_dates_df, SP_dates, on=["Date"])
SP_GCr_corr = st.pearsonr(forcorr_df["Gold-Copp Dly Ret"],forcorr_df["SP_Daily_Pct_Return"])[0]
print(SP_GCr_corr)
# Out:
# 0.2614556960271628

# %%
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
line1 = ax1.plot(SP_dates['Date'], SP_dates['Settle'], "b-")
plt.xticks(rotation = 45)
plt.ylabel("SP 500 Close Price")

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
line2= ax2.plot(copp_gold_dates_df['Date'],copp_gold_dates_df['Gold-Copp Dly Ret'], "r-")
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")
plt.xticks(rotation=45)
plt.ylabel("Copper Gold daily Chg")

ax1.legend((line1+line2), ("SP 500 Close Price", "Gold Copper Daily Chg"), loc=0)
plt.title("1997 through current SP Price vs CGr daily change")
plt.xlabel("Date")
plt.grid(alpha=1)
fig1.savefig("1997 through current SP Price vs CGr daily change")
plt.show()

# %%
copp_gold_dates_df['MA'] = copp_gold_dates_df.rolling(55).mean()['Gold-Copp Dly Ret']
copp_gold_dates_df.tail(5)
# Out:
# C:\Users\bruce\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Date  Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio  \
# 8678 2020-06-04              -1.23      1727.4        2.4895         0.001441
# 8679 2020-06-05               5.36      1683.0        2.5555         0.001518
# 8680 2020-06-08              -0.91      1705.1        2.5655         0.001505
# 8681 2020-06-09               0.32      1721.9        2.5990         0.001509
# 8682 2020-06-10               2.28      1720.7        2.6565         0.001544
#
#             MA
# 8678 -0.066545
# 8679  0.102545
# 8680  0.056909
# 8681  0.080727
# 8682  0.275091

# %%
copp_gold_dates_df['rolling_std'] = copp_gold_dates_df.rolling(55).std()['Gold-Copp Dly Ret']
copp_gold_dates_df.tail(5)
# Out:
# C:\Users\bruce\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Date  Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio  \
# 8678 2020-06-04              -1.23      1727.4        2.4895         0.001441
# 8679 2020-06-05               5.36      1683.0        2.5555         0.001518
# 8680 2020-06-08              -0.91      1705.1        2.5655         0.001505
# 8681 2020-06-09               0.32      1721.9        2.5990         0.001509
# 8682 2020-06-10               2.28      1720.7        2.6565         0.001544
#
#             MA  rolling_std
# 8678 -0.066545     2.343876
# 8679  0.102545     2.394182
# 8680  0.056909     2.389027
# 8681  0.080727     2.384922
# 8682  0.275091     2.098548

# %%
SP_filter_df = SP_dates.loc[(SP_dates["Date"] >= "2018-06-11") & 
                                   (SP_dates["Date"] <= "2020-06-10")]
SP_filter_df.head()
# Out:
#            Date  SP_Daily_Pct_Return     Open     High      Low     Last  \
# 5286 2018-06-11                 0.15  2776.75  2794.25  2774.00  2786.00
# 5287 2018-06-12                 0.05  2785.00  2794.00  2782.25  2792.50
# 5288 2018-06-13                -0.33  2792.00  2796.00  2778.50  2779.50
# 5289 2018-06-14                 0.34  2777.75  2794.00  2772.25  2788.25
# 5290 2018-06-15                -0.14  2787.00  2788.50  2765.50  2781.50
#
#       Change   Settle     Volume  Previous Day Open Interest     SP_MA
# 5286    4.25  2786.75  1546322.0                   1142120.0  0.096182
# 5287    1.50  2788.25  1486877.0                   1809743.0  0.128727
# 5288    9.25  2779.00  1371929.0                   2283691.0  0.079455
# 5289    9.50  2788.50  1251575.0                   2499069.0  0.115818
# 5290    4.00  2784.50  1475397.0                   2602004.0  0.118909

# %%
CGr_filter_df = copp_gold_dates_df.loc[(copp_gold_dates_df["Date"] >= "1998-06-11") & 
                                   (copp_gold_dates_df["Date"] <= "2020-06-10")]
CGr_filter_df.head()
# Out:
#            Date  Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio  \
# 3209 1998-06-11              -0.01       288.7        0.7635         0.002645
# 3210 1998-06-12              -0.76       287.3        0.7540         0.002624
# 3211 1998-06-15              -2.55       286.6        0.7330         0.002558
# 3212 1998-06-16              -0.84       290.0        0.7355         0.002536
# 3213 1998-06-17               0.14       294.9        0.7490         0.002540
#
#       MA  rolling_std
# 3209 NaN          NaN
# 3210 NaN          NaN
# 3211 NaN          NaN
# 3212 NaN          NaN
# 3213 NaN          NaN

# %%
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
line1 = ax1.plot(SP_filter_df['Date'], SP_filter_df['Settle'], "b-")
plt.xticks(rotation = 45)
plt.ylabel("SP 500 Close Price")

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
line2= ax2.plot(CGr_filter_df['Date'],CGr_filter_df['MA'], "r-")
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")
plt.xticks(rotation=45)
plt.ylabel("Copper Gold daily Chg")

# ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
# line3= ax2.plot(CGr_filter_df['Date'],CGr_filter_df['rolling_std'], "g-")
# ax2.yaxis.tick_right()
# ax2.yaxis.set_label_position("right")
# plt.xticks(rotation=45)
# plt.ylabel("Copper Gold daily Chg")

ax1.legend((line1+line2+line3), ("SP 500 Close Price", "Gold Copper Daily Chg MA", "GoldCopp Rolling Std"), loc=0)
# ax1.legend((line1+line2), ("SP 500 Close Price", "Gold Copper Daily Chg MA"), loc=0)
plt.title("Jan 2017 to Pres - SP 500 Close Price vs.Copper Gold Metrics")
plt.xlabel("Date")
plt.grid(alpha=1)
# fig1.savefig("Jan 2017 to Pres. vs Gold Copper daily ret metrics")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c855f41cbe08> in <module>
#      19 # plt.ylabel("Copper Gold daily Chg")
#      20
# ---> 21 ax1.legend((line1+line2+line3), ("SP 500 Close Price", "Gold Copper Daily Chg MA", "GoldCopp Rolling Std"), loc=0)
#      22 # ax1.legend((line1+line2), ("SP 500 Close Price", "Gold Copper Daily Chg MA"), loc=0)
#      23 plt.title("Jan 2017 to Pres - SP 500 Close Price vs.Copper Gold Metrics")
#
# NameError: name 'line3' is not defined

# %%
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
line1 = ax1.plot(SP_filter_df['Date'], SP_filter_df['Settle'], "b-")
plt.xticks(rotation = 45)
plt.ylabel("SP 500 Close Price")

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
line2= ax2.plot(CGr_filter_df['Date'],CGr_filter_df['MA'], "r-")
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")
plt.xticks(rotation=45)
plt.ylabel("daily Chg")

# ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
# line3= ax2.plot(copp_gold_covid_df['Date'],copp_gold_covid_df['rolling_std'], "g-")
# ax2.yaxis.tick_right()
# ax2.yaxis.set_label_position("right")
# plt.xticks(rotation=45)
# plt.ylabel("Copper Gold daily Chg")

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
line4= ax2.plot(SP_filter_df['Date'],SP_filter_df['SP_MA'], "y-")
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")
plt.xticks(rotation=45)
plt.ylabel("daily Chg")

ax1.legend((line1+line2+line3+line4), ("SP 500 Close Price", "Gold Copper Daily Chg MA", "GoldCopp Rolling Std", "SP500 daily % MA"), loc=0)
# ax1.legend((line1+line2), ("SP 500 Close Price", "Gold Copper Daily Chg MA"), loc=0)
plt.title("SP500 Cgr Metrics")
plt.xlabel("Date")
plt.grid(alpha=1)
# fig1.savefig("Jan 2017 to Pres. vs Gold Copper daily ret metrics")
plt.show()
# Out:
# C:\Users\bruce\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-e442e59f0b72> in <module>
#      26 plt.ylabel("daily Chg")
#      27
# ---> 28 ax1.legend((line1+line2+line3+line4), ("SP 500 Close Price", "Gold Copper Daily Chg MA", "GoldCopp Rolling Std", "SP500 daily % MA"), loc=0)
#      29 # ax1.legend((line1+line2), ("SP 500 Close Price", "Gold Copper Daily Chg MA"), loc=0)
#      30 plt.title("SP500 Cgr Metrics")
#
# NameError: name 'line3' is not defined

# %%
# Rolling Correlation
Rolling_window = 55
Rolling_correl =55
no_of_std = 2
correl = forcorr_df['SP_Daily_Pct_Return'].rolling(window=Rolling_window).corr(forcorr_df['Gold-Copp Dly Ret'])
correl_mean = correl.rolling(window=Rolling_correl).mean()
# print(correl_mean)
# Standard Deviation from mean
std_correl = correl.rolling(window=Rolling_correl).std()
# Upper and lower bounds for correl
upper_correl = correl_mean + (std_correl * no_of_std )
lower_correl = correl_mean - (std_correl * no_of_std )
# correl.tail()
lower_correl.tail()
# Out:
# 5511    0.059577
# 5512    0.062634
# 5513    0.066235
# 5514    0.071039
# 5515    0.068468
# dtype: float64

# %%
forcorr_df.tail()
# Out:
#            Date  Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio  \
# 5511 2020-06-04              -1.23      1727.4        2.4895         0.001441
# 5512 2020-06-05               5.36      1683.0        2.5555         0.001518
# 5513 2020-06-08              -0.91      1705.1        2.5655         0.001505
# 5514 2020-06-09               0.32      1721.9        2.5990         0.001509
# 5515 2020-06-10               2.28      1720.7        2.6565         0.001544
#
#       SP_Daily_Pct_Return     Open     High      Low    Last  Change   Settle  \
# 5511                -0.22  3106.75  3115.75  3077.00  3103.0    6.75  3099.75
# 5512                 2.48  3102.25  3199.75  3096.00  3175.0   76.75  3176.50
# 5513                 1.27  3181.50  3220.50  3173.00  3215.5   40.25  3216.75
# 5514                -0.69  3216.00  3220.00  3179.00  3194.5   22.25  3194.50
# 5515                -0.59  3194.25  3216.75  3168.75  3173.5   19.00  3175.50
#
#         Volume  Previous Day Open Interest     SP_MA
# 5511   31864.0                     57382.0  0.435818
# 5512   56532.0                     66325.0  0.542364
# 5513   89946.0                     75367.0  0.574909
# 5514   92923.0                    127169.0  0.638909
# 5515  160381.0                    151588.0  0.688000

# %%
SP_GCR_corr_df = pd.merge(SP500_df, copp_gold_df, on=["Date"])
SP_GCR_corr = st.pearsonr(SP_GCR_corr_df["SP_Daily_Pct_Return"],SP_GCR_corr_df["Gold-Copp Dly Ret"])[0]
print(SP_GCR_corr)
# Out:
# 0.25690739418896813

# %%
Rolling_window = 55
Rolling_correl =55
no_of_std = 2
correl = SP_GCR_corr_df['SP_Daily_Pct_Return'].rolling(window=Rolling_window).corr(SP_GCR_corr_df['Gold-Copp Dly Ret'])
correl_mean = correl.rolling(window=Rolling_correl).mean()
print(correl_mean)
# Standard Deviation from mean
std_correl = correl.rolling(window=Rolling_correl).std()
# Upper and lower bounds for correl
upper_correl = correl_mean + (std_correl * no_of_std )
lower_correl = correl_mean - (std_correl * no_of_std )
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5661    0.133223
# 5662    0.132673
# 5663    0.131858
# 5664    0.132827
# 5665    0.134341
# Length: 5666, dtype: float64

# %%
summary_df = pd.DataFrame({'Date': SP_GCR_corr_df['Date'],
                                      'dly chg correlation': correl,
                                      'dly chg corr mean': correl_mean,
                                      'Std daily chg correl':std_correl,
                                      'upper_correl': upper_correl,
                                      'lower_correl':lower_correl})

summary_df = summary_df.loc[(SP_dates["Date"] >= "1998-04-15") & 
                                   (SP_dates["Date"] <= "2020-06-10")]


summary_df.head(150)
# Out:
#           Date  dly chg correlation  dly chg corr mean  Std daily chg correl  \
# 152 1998-04-20             0.011009          -0.033064              0.048754
# 153 1998-04-21            -0.006357          -0.032348              0.048854
# 154 1998-04-22             0.016310          -0.031263              0.049265
# 155 1998-04-23             0.030037          -0.029908              0.049915
# 156 1998-04-24             0.045383          -0.028229              0.050875
# ..         ...                  ...                ...                   ...
# 297 1998-11-12             0.382866           0.363025              0.051947
# 298 1998-11-13             0.494902           0.368822              0.048365
# 299 1998-11-16             0.495549           0.374434              0.044627
# 300 1998-11-17             0.519461           0.380043              0.043061
# 301 1998-11-18             0.440569           0.382382              0.042785
#
#      upper_correl  lower_correl
# 152      0.064444     -0.130572
# 153      0.065359     -0.130055
# 154      0.067268     -0.129794
# 155      0.069923     -0.129739
# 156      0.073521     -0.129979
# ..            ...           ...
# 297      0.466919      0.259132
# 298      0.465551      0.272093
# 299      0.463687      0.285181
# 300      0.466165      0.293921
# 301      0.467953      0.296811
#
# [150 rows x 6 columns]

# %%
def my_signal(row):
    if row['dly chg correlation']> row ['upper_correl']:
        return row['dly chg correlation'] - row['upper_correl']
    elif row['dly chg correlation'] < row['lower_correl']:
        return row['dly chg correlation'] - row['lower_correl']
    else:
        return 0
    
summary_df['signal'] = summary_df.apply(my_signal, axis=1)
summary_df
# Out:
#            Date  dly chg correlation  dly chg corr mean  Std daily chg correl  \
# 152  1998-04-20             0.011009          -0.033064              0.048754
# 153  1998-04-21            -0.006357          -0.032348              0.048854
# 154  1998-04-22             0.016310          -0.031263              0.049265
# 155  1998-04-23             0.030037          -0.029908              0.049915
# 156  1998-04-24             0.045383          -0.028229              0.050875
# ...         ...                  ...                ...                   ...
# 5661 2020-06-10             0.009343           0.133223              0.032378
# 5662 2020-06-11             0.183151           0.132673              0.031227
# 5663 2020-06-12             0.178245           0.131858              0.029353
# 5664 2020-06-15             0.242373           0.132827              0.032034
# 5665 2020-06-16             0.255652           0.134341              0.035697
#
#       upper_correl  lower_correl    signal
# 152       0.064444     -0.130572  0.000000
# 153       0.065359     -0.130055  0.000000
# 154       0.067268     -0.129794  0.000000
# 155       0.069923     -0.129739  0.000000
# 156       0.073521     -0.129979  0.000000
# ...            ...           ...       ...
# 5661      0.197978      0.068468 -0.059125
# 5662      0.195127      0.070219  0.000000
# 5663      0.190563      0.073152  0.000000
# 5664      0.196896      0.068758  0.045477
# 5665      0.205735      0.062947  0.049917
#
# [5514 rows x 7 columns]

# %%
summary_df
# Out:
#            Date  dly chg correlation  dly chg corr mean  Std daily chg correl  \
# 152  1998-04-20             0.011009          -0.033064              0.048754
# 153  1998-04-21            -0.006357          -0.032348              0.048854
# 154  1998-04-22             0.016310          -0.031263              0.049265
# 155  1998-04-23             0.030037          -0.029908              0.049915
# 156  1998-04-24             0.045383          -0.028229              0.050875
# ...         ...                  ...                ...                   ...
# 5661 2020-06-10             0.009343           0.133223              0.032378
# 5662 2020-06-11             0.183151           0.132673              0.031227
# 5663 2020-06-12             0.178245           0.131858              0.029353
# 5664 2020-06-15             0.242373           0.132827              0.032034
# 5665 2020-06-16             0.255652           0.134341              0.035697
#
#       upper_correl  lower_correl    signal
# 152       0.064444     -0.130572  0.000000
# 153       0.065359     -0.130055  0.000000
# 154       0.067268     -0.129794  0.000000
# 155       0.069923     -0.129739  0.000000
# 156       0.073521     -0.129979  0.000000
# ...            ...           ...       ...
# 5661      0.197978      0.068468 -0.059125
# 5662      0.195127      0.070219  0.000000
# 5663      0.190563      0.073152  0.000000
# 5664      0.196896      0.068758  0.045477
# 5665      0.205735      0.062947  0.049917
#
# [5514 rows x 7 columns]

# %%
# print(summary_df.isnull().sum())
# final_df.dropna(inplace=True)
# print(final_df.isnull().sum())
# final_df

# %%
summary2_df = pd.merge(SP_filter_df, summary_df, on=["Date"])
summary3_df = pd.merge(summary2_df, CGr_filter_df, on=["Date"])
summary3_df.tail()
# Out:
#           Date  SP Daily Pct Return     Open     High      Low    Last  \
# 499 2020-06-04                -0.22  3106.75  3115.75  3077.00  3103.0
# 500 2020-06-05                 2.48  3102.25  3199.75  3096.00  3175.0
# 501 2020-06-08                 1.27  3181.50  3220.50  3173.00  3215.5
# 502 2020-06-09                -0.69  3216.00  3220.00  3179.00  3194.5
# 503 2020-06-10                -0.59  3194.25  3216.75  3168.75  3173.5
#
#      Change   Settle    Volume  Previous Day Open Interest  ...  \
# 499    6.75  3099.75   31864.0                     57382.0  ...
# 500   76.75  3176.50   56532.0                     66325.0  ...
# 501   40.25  3216.75   89946.0                     75367.0  ...
# 502   22.25  3194.50   92923.0                    127169.0  ...
# 503   19.00  3175.50  160381.0                    151588.0  ...
#
#      Std daily chg correl  upper_correl  lower_correl    signal  \
# 499              0.042730      0.230498      0.059577  0.000000
# 500              0.040072      0.222922      0.062634  0.000000
# 501              0.037190      0.214997      0.066235  0.000000
# 502              0.033527      0.205148      0.071039  0.000000
# 503              0.032378      0.197978      0.068468 -0.059125
#
#      Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio        MA  \
# 499              -1.23      1727.4        2.4895         0.001441 -0.066545
# 500               5.36      1683.0        2.5555         0.001518  0.102545
# 501              -0.91      1705.1        2.5655         0.001505  0.056909
# 502               0.32      1721.9        2.5990         0.001509  0.080727
# 503               2.28      1720.7        2.6565         0.001544  0.275091
#
#      rolling_std
# 499     2.343876
# 500     2.394182
# 501     2.389027
# 502     2.384922
# 503     2.098548
#
# [5 rows x 23 columns]

# %%
fig1 = plt.figure(figsize=(10,7))
ax1 = fig1.add_subplot(111)
line1 = ax1.plot(summary3_df['Date'], summary3_df['Settle'], "b-")
plt.xticks(rotation = 45)
plt.ylabel("SP 500 Close Price")

# ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
# line2= ax2.plot(summary3_df['Date'],summary3_df['MA'], "r-")
# ax2.yaxis.tick_right()
# ax2.yaxis.set_label_position("right")
# plt.xticks(rotation=45)
# plt.ylabel("daily Chg")

# ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
# line3= ax2.plot(copp_gold_covid_df['Date'],copp_gold_covid_df['rolling_std'], "g-")
# ax2.yaxis.tick_right()
# ax2.yaxis.set_label_position("right")
# plt.xticks(rotation=45)
# plt.ylabel("Copper Gold daily Chg")

# ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
# line4= ax2.plot(summary3_df['Date'],summary3_df['SP_MA'], "y-")
# ax2.yaxis.tick_right()
# ax2.yaxis.set_label_position("right")
# plt.xticks(rotation=45)
# plt.ylabel("daily Chg")



# ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
# line5= ax2.plot(summary3_df['Date'],summary3_df['upper_correl'], "m-")
# ax2.yaxis.tick_right()
# ax2.yaxis.set_label_position("right")
# plt.xticks(rotation=45)
# plt.ylabel("daily Chg")


# ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
# line6= ax2.plot(summary3_df['Date'],summary3_df['lower_correl'], "m-")
# ax2.yaxis.tick_right()
# ax2.yaxis.set_label_position("right")
# plt.xticks(rotation=45)
# plt.ylabel("daily Chg")

ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
line7= ax2.plot(summary3_df['Date'],summary3_df['signal'], "r-")
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")
plt.xticks(rotation=45)
plt.ylabel("daily Chg")


ax1.legend((line1+line2+line3+line4+line5+line6), ("SP 500 Close Price", "Gold Copper Daily Chg MA", "GoldCopp Rolling Std", "SP500 daily % MA"), loc=0)
# ax1.legend((line1+line2), ("SP 500 Close Price", "Gold Copper Daily Chg MA"), loc=0)
plt.title("SP500 Cgr Metrics")
plt.xlabel("Date")
plt.grid(alpha=1)
# fig1.savefig("Jan 2017 to Pres. vs Gold Copper daily ret metrics")



plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-215-131287bed4cd> in <module>
#      51
#      52
# ---> 53 ax1.legend((line1+line2+line3+line4+line5+line6), ("SP 500 Close Price", "Gold Copper Daily Chg MA", "GoldCopp Rolling Std", "SP500 daily % MA"), loc=0)
#      54 # ax1.legend((line1+line2), ("SP 500 Close Price", "Gold Copper Daily Chg MA"), loc=0)
#      55 plt.title("SP500 Cgr Metrics")
#
# NameError: name 'line3' is not defined

# %%
summary3_df.to_csv('jun18tojun20.csv', encoding='utf-8')

# %%
SP_GCR_Summary_df = pd.dataframe()
SP_GCR_Summary_df = pd.DataFrame([{"dly chg correlation": correl,
                            "dly chg corr mean": correl_mean,
                            "dly chg Std":std_correl,
                            "upper std": upper_correl
                            "lower std": lower_correl,}])

SP_GCR_Summary_df["# dly chg correlation"] = summary_df["# of Transactions"]
summary_df["Total Unique Items"] = summary_df["Total Unique Items"]
summary_df["Avg. Price"] = summary_df["Avg. Price"]
summary_df["Total Revenue"] = summary_df["Total Revenue"]
# Out:
#   File "<ipython-input-39-33c1bb89de68>", line 6
#     "lower std": lower_correl,}])
#               ^
# SyntaxError: invalid syntax

# %%
SP_GCR_corr_df['SP_Daily_Pct_Return'] = SP_GCR_corr_df.rolling(55).corr()['Gold-Copp Dly Ret']
SP_GCR_corr_df.tail(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-56d69e9f6aec> in <module>
# ----> 1 SP_GCR_corr_df['SP Daily Pct Return'] = SP_GCR_corr_df.rolling(55).corr()['Gold-Copp Dly Ret']
#       2 SP_GCR_corr_df.tail(5)
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in corr(self, other, pairwise, **kwargs)
#    1948     @Appender(_shared_docs["corr"])
#    1949     def corr(self, other=None, pairwise=None, **kwargs):
# -> 1950         return super().corr(other=other, pairwise=pairwise, **kwargs)
#    1951
#    1952
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in corr(self, other, pairwise, **kwargs)
#    1680
#    1681         return _flex_binary_moment(
# -> 1682             self._selected_obj, other._selected_obj, _get_corr, pairwise=bool(pairwise)
#    1683         )
#    1684
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in _flex_binary_moment(arg1, arg2, f, pairwise)
#    2686                         else:
#    2687                             results[i][j] = f(
# -> 2688                                 *_prep_binary(arg1.iloc[:, i], arg2.iloc[:, j])
#    2689                             )
#    2690
#
# ~\Anaconda3\lib\site-packages\pandas\core\window.py in _prep_binary(arg1, arg2)
#    2831
#    2832     # mask out values, this also makes a common index...
# -> 2833     X = arg1 + 0 * arg2
#    2834     Y = arg2 + 0 * arg1
#    2835
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     990             # test_dt64_series_add_intlike, which the index dispatching handles
#     991             # specifically.
# --> 992             result = dispatch_to_index_op(op, left, right, pd.DatetimeIndex)
#     993             return construct_result(
#     994                 left, result, index=left.index, name=res_name, dtype=result.dtype
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_index_op(op, left, right, index_class)
#     628         left_idx = left_idx._shallow_copy(freq=None)
#     629     try:
# --> 630         result = op(left_idx, right)
#     631     except NullFrequencyError:
#     632         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\roperator.py in rmul(left, right)
#      15
#      16 def rmul(left, right):
# ---> 17     return right * left
#      18
#      19
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in invalid_op(self, other)
#     194         raise TypeError(
#     195             "cannot perform {name} with this index type: "
# --> 196             "{typ}".format(name=name, typ=type(self).__name__)
#     197         )
#     198
#
# TypeError: cannot perform __rmul__ with this index type: DatetimeIndex

# %%
print(upper_correl)
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 5659    0.214997
# 5660    0.205148
# 5661    0.197978
# 5662    0.195127
# 5663    0.190563
# Length: 5664, dtype: float64

# %%
lower_correl.tail(20)
# Out:
# 5644   -0.001486
# 5645   -0.001578
# 5646   -0.001472
# 5647    0.000796
# 5648    0.003508
# 5649    0.007838
# 5650    0.013534
# 5651    0.020725
# 5652    0.032622
# 5653    0.043065
# 5654    0.043071
# 5655    0.050417
# 5656    0.058033
# 5657    0.059577
# 5658    0.062634
# 5659    0.066235
# 5660    0.071039
# 5661    0.068468
# 5662    0.070219
# 5663    0.073152
# dtype: float64

# %%
SP_GCR_corr_df.head(5)
# Out:
#         Date  SP Daily Pct Return    Open    High     Low    Last  Change  \
# 0 1997-09-09                 0.05  943.50  951.00  941.50  944.00     NaN
# 1 1997-09-10                -2.01  942.75  943.25  917.00  925.00     NaN
# 2 1997-09-11                -0.73  924.00  929.75  910.25  918.25     NaN
# 3 1997-09-12                 1.69  918.00  936.50  913.50  933.75     NaN
# 4 1997-09-15                -0.24  933.50  939.75  929.00  931.50     NaN
#
#    Settle   Volume  Previous Day Open Interest  Gold-Copp Dly Ret  Gold Price  \
# 0  944.00    896.0                       273.0               0.05       324.1
# 1  925.00  12261.0                       382.0               0.31       324.1
# 2  918.25   9759.0                      2909.0              -3.58       326.6
# 3  933.75  18496.0                      4059.0               0.44       326.2
# 4  931.50  11749.0                      3818.0               0.67       324.7
#
#    Copper Price  GoldCopperRatio
# 0        0.9655         0.002979
# 1        0.9685         0.002988
# 2        0.9410         0.002881
# 3        0.9440         0.002894
# 4        0.9460         0.002913

# %%
summary3_df.tail()
# Out:
#            Date  SP Daily Pct Return     Open     High      Low    Last  \
# 5077 2020-06-04                -0.22  3106.75  3115.75  3077.00  3103.0
# 5078 2020-06-05                 2.48  3102.25  3199.75  3096.00  3175.0
# 5079 2020-06-08                 1.27  3181.50  3220.50  3173.00  3215.5
# 5080 2020-06-09                -0.69  3216.00  3220.00  3179.00  3194.5
# 5081 2020-06-10                -0.59  3194.25  3216.75  3168.75  3173.5
#
#       Change   Settle    Volume  Previous Day Open Interest  ...  \
# 5077    6.75  3099.75   31864.0                     57382.0  ...
# 5078   76.75  3176.50   56532.0                     66325.0  ...
# 5079   40.25  3216.75   89946.0                     75367.0  ...
# 5080   22.25  3194.50   92923.0                    127169.0  ...
# 5081   19.00  3175.50  160381.0                    151588.0  ...
#
#       Std daily chg correl  upper_correl  lower_correl    signal  \
# 5077              0.042730      0.230498      0.059577  0.000000
# 5078              0.040072      0.222922      0.062634  0.000000
# 5079              0.037190      0.214997      0.066235  0.000000
# 5080              0.033527      0.205148      0.071039  0.000000
# 5081              0.032378      0.197978      0.068468 -0.059125
#
#       Gold-Copp Dly Ret  Gold Price  Copper Price  GoldCopperRatio        MA  \
# 5077              -1.23      1727.4        2.4895         0.001441 -0.066545
# 5078               5.36      1683.0        2.5555         0.001518  0.102545
# 5079              -0.91      1705.1        2.5655         0.001505  0.056909
# 5080               0.32      1721.9        2.5990         0.001509  0.080727
# 5081               2.28      1720.7        2.6565         0.001544  0.275091
#
#       rolling_std
# 5077     2.343876
# 5078     2.394182
# 5079     2.389027
# 5080     2.384922
# 5081     2.098548
#
# [5 rows x 23 columns]

# %%
csv_file = os.path.join("CGr_model_returns.csv")
CGr_returns_df = pd.read_csv(csv_file)
CGr_returns_df["period"] = pd.to_datetime(CGr_returns_df["period"])
# CGr_returns_df['Capital'] = CGr_returns_df['Capital'].astype(float)
CGr_returns_df.drop(CGr_returns_df.columns[[5]], axis=1, inplace=True)
CGr_returns_df.dropna(inplace=True)
CGr_returns_df.head(12)
# Out:
#        period  CGr + Model ret  Ltd  return   CGr+ PL   Capital
# 0  1998-06-15             0.00         0.00      0.00  100000.00
# 1  2000-06-15             0.18         0.18  18406.00  118406.00
# 2  2002-06-15             0.30         0.54  35985.44  154391.44
# 3  2004-06-15             0.18         0.81  27027.68  181419.12
# 4  2006-06-15             0.07         0.94  12318.65  193737.77
# 5  2008-06-15             0.08         1.09  15455.55  209193.32
# 6  2010-06-15            -0.23         0.60 -49026.20  160167.12
# 7  2012-06-15             0.19         0.90  29738.38  189905.50
# 8  2014-06-15             0.15         1.18  27607.13  217512.63
# 9  2016-06-15             0.19         1.59  41405.12  258917.76
# 10 2018-06-15             0.01         1.63   3864.70  262782.45
# 11 2020-06-15             0.09         1.87  24098.43  286880.88

# %%
plt.bar(CGr_returns_df['period'],CGr_returns_df['Capital'])
plt.title("CGr Model Capital Growth")
plt.xticks(rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Capital'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-247-059e3e673e2a> in <module>
# ----> 1 plt.bar(CGr_returns_df['period'],CGr_returns_df['Capital'])
#       2 plt.title("CGr Model Capital Growth")
#       3 plt.xticks(rotation = 90)
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Capital'
